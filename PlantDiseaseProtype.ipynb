# %% [markdown]
# # Plant Disease Classification using CNN

# %%
#imoprt the requied packages for the model
import numpy as np
import pickle
import cv2
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#defining the epochs, learning rate, batch size, def image size, dataset root, HWD
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((256, 256))
image_size = 0
directory_root = '../input/plantdisease'
width=256
height=256
depth=3

# %%
#converting imgaes to array using opencv functions
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
#taking images from the defined directory
image_list, label_list = [], []
try:
    root_dir = listdir(directory_root)
    for directory in root_dir :
        if directory == ".DS_Store" :
            root_dir.remove(directory)
#defining the root path
    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"{plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list[:200]:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)  
except Exception as e:
    print(f"Error : {e}")
#printing the available cirecctories in the dataset
# Out:
# Pepper__bell___Bacterial_spot ...
# Potato___healthy ...
# Tomato_Leaf_Mold ...
# Tomato__Tomato_YellowLeaf__Curl_Virus ...
# Tomato_Bacterial_spot ...
# Tomato_Septoria_leaf_spot ...
# Tomato_healthy ...
# Tomato_Spider_mites_Two_spotted_spider_mite ...
# Tomato_Early_blight ...
# Tomato__Target_Spot ...
# Pepper__bell___healthy ...
# Potato___Late_blight ...
# Tomato_Late_blight ...
# Potato___Early_blight ...
# Tomato__Tomato_mosaic_virus ...
# PlantVillage ...

# %%
#getting the size of processed image
image_size = len(image_list)
print(image_size)
# Out:
# 2952

# %%
#using scikit label binarizer
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
#printing the labels of the available classes
print(label_binarizer.classes_)
# Out:
# ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy'
#  'Tomato_Bacterial_spot' 'Tomato_Early_blight' 'Tomato_Late_blight'
#  'Tomato_Leaf_Mold' 'Tomato_Septoria_leaf_spot'
#  'Tomato_Spider_mites_Two_spotted_spider_mite' 'Tomato__Target_Spot'
#  'Tomato__Tomato_YellowLeaf__Curl_Virus' 'Tomato__Tomato_mosaic_virus'
#  'Tomato_healthy']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 255.0

# %%
#split data to train and test
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %%
#building the CNN model
model = Sequential()
inputShape = (height, width, depth)
chanDim = -1
if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1
model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(n_classes))
model.add(Activation("softmax"))

# %%
#to generate the model characteristics
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# activation (Activation)      (None, 256, 256, 32)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 85, 85, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 85, 85, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 85, 85, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 42, 42, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 42, 42, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 42, 42, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 42, 42, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 56448)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              57803776
# _________________________________________________________________
# activation_5 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                15375
# _________________________________________________________________
# activation_6 (Activation)    (None, 15)                0
# =================================================================
# Total params: 58,102,671
# Trainable params: 58,099,791
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network

# %% [markdown]
# **Training**

# %%
history = model.fit_generator(
    aug.flow(x_train, y_train, batch_size=BS),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // BS,
    epochs=EPOCHS, verbose=1
    )
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 73/73 [==============================] - 56s 663ms/step - loss: 2.7515 - accuracy: 0.3046 - val_loss: 16.0562 - val_accuracy: 0.0728
# Epoch 2/50
# 73/73 [==============================] - 45s 609ms/step - loss: 1.6517 - accuracy: 0.5210 - val_loss: 14.9455 - val_accuracy: 0.0694
# Epoch 3/50
# 73/73 [==============================] - 44s 607ms/step - loss: 1.4518 - accuracy: 0.5739 - val_loss: 10.7137 - val_accuracy: 0.1032
# Epoch 4/50
# 73/73 [==============================] - 45s 613ms/step - loss: 1.1740 - accuracy: 0.6325 - val_loss: 13.2444 - val_accuracy: 0.0728
# Epoch 5/50
# 73/73 [==============================] - 44s 607ms/step - loss: 0.9627 - accuracy: 0.6973 - val_loss: 10.7452 - val_accuracy: 0.1184
# Epoch 6/50
# 73/73 [==============================] - 45s 609ms/step - loss: 0.8461 - accuracy: 0.7092 - val_loss: 5.2707 - val_accuracy: 0.3080
# Epoch 7/50
# 73/73 [==============================] - 45s 613ms/step - loss: 0.7772 - accuracy: 0.7563 - val_loss: 3.0866 - val_accuracy: 0.4027
# Epoch 8/50
# 73/73 [==============================] - 45s 608ms/step - loss: 0.6668 - accuracy: 0.7807 - val_loss: 1.4816 - val_accuracy: 0.6345
# Epoch 9/50
# 73/73 [==============================] - 44s 605ms/step - loss: 0.6454 - accuracy: 0.7811 - val_loss: 2.9524 - val_accuracy: 0.4704
# Epoch 10/50
# 73/73 [==============================] - 45s 615ms/step - loss: 0.7889 - accuracy: 0.7619 - val_loss: 3.0127 - val_accuracy: 0.4535
# Epoch 11/50
# 73/73 [==============================] - 44s 603ms/step - loss: 0.6358 - accuracy: 0.7898 - val_loss: 0.7592 - val_accuracy: 0.7631
# Epoch 12/50
# 73/73 [==============================] - 44s 605ms/step - loss: 0.5444 - accuracy: 0.8257 - val_loss: 2.0096 - val_accuracy: 0.6108
# Epoch 13/50
# 73/73 [==============================] - 45s 610ms/step - loss: 0.5168 - accuracy: 0.8243 - val_loss: 6.8011 - val_accuracy: 0.3672
# Epoch 14/50
# 73/73 [==============================] - 44s 599ms/step - loss: 0.5677 - accuracy: 0.8012 - val_loss: 1.2139 - val_accuracy: 0.6870
# Epoch 15/50
# 73/73 [==============================] - 44s 602ms/step - loss: 0.5889 - accuracy: 0.8125 - val_loss: 7.1886 - val_accuracy: 0.2910
# Epoch 16/50
# 73/73 [==============================] - 45s 613ms/step - loss: 0.6289 - accuracy: 0.7979 - val_loss: 6.8104 - val_accuracy: 0.2809
# Epoch 17/50
# 73/73 [==============================] - 44s 604ms/step - loss: 0.5782 - accuracy: 0.8069 - val_loss: 20.7257 - val_accuracy: 0.1337
# Epoch 18/50
# 73/73 [==============================] - 44s 604ms/step - loss: 0.7074 - accuracy: 0.7717 - val_loss: 3.7328 - val_accuracy: 0.4179
# Epoch 19/50
# 73/73 [==============================] - 44s 607ms/step - loss: 0.7763 - accuracy: 0.7364 - val_loss: 4.9549 - val_accuracy: 0.4044
# Epoch 20/50
# 73/73 [==============================] - 45s 609ms/step - loss: 0.4914 - accuracy: 0.8404 - val_loss: 4.1091 - val_accuracy: 0.4552
# Epoch 21/50
# 73/73 [==============================] - 44s 605ms/step - loss: 0.4918 - accuracy: 0.8363 - val_loss: 2.6070 - val_accuracy: 0.5533
# Epoch 22/50
# 73/73 [==============================] - 45s 611ms/step - loss: 0.3684 - accuracy: 0.8764 - val_loss: 8.3457 - val_accuracy: 0.2758
# Epoch 23/50
# 73/73 [==============================] - 44s 608ms/step - loss: 0.4411 - accuracy: 0.8482 - val_loss: 2.9318 - val_accuracy: 0.5178
# Epoch 24/50
# 73/73 [==============================] - 44s 602ms/step - loss: 0.3613 - accuracy: 0.8786 - val_loss: 2.3487 - val_accuracy: 0.5195
# Epoch 25/50
# 73/73 [==============================] - 45s 609ms/step - loss: 0.3654 - accuracy: 0.8847 - val_loss: 3.0721 - val_accuracy: 0.5651
# Epoch 26/50
# 73/73 [==============================] - 44s 600ms/step - loss: 0.3602 - accuracy: 0.8751 - val_loss: 1.7219 - val_accuracy: 0.6717
# Epoch 27/50
# 73/73 [==============================] - 44s 607ms/step - loss: 0.2955 - accuracy: 0.8920 - val_loss: 4.7579 - val_accuracy: 0.4552
# Epoch 28/50
# 73/73 [==============================] - 45s 612ms/step - loss: 0.3072 - accuracy: 0.9029 - val_loss: 4.9726 - val_accuracy: 0.3570
# Epoch 29/50
# 73/73 [==============================] - 44s 602ms/step - loss: 0.2911 - accuracy: 0.8954 - val_loss: 3.1018 - val_accuracy: 0.5601
# Epoch 30/50
# 73/73 [==============================] - 44s 608ms/step - loss: 0.2875 - accuracy: 0.8999 - val_loss: 1.2939 - val_accuracy: 0.7073
# Epoch 31/50
# 73/73 [==============================] - 45s 613ms/step - loss: 0.3066 - accuracy: 0.8983 - val_loss: 1.8948 - val_accuracy: 0.6836
# Epoch 32/50
# 73/73 [==============================] - 44s 604ms/step - loss: 0.2910 - accuracy: 0.9033 - val_loss: 0.9389 - val_accuracy: 0.7479
# Epoch 33/50
# 73/73 [==============================] - 44s 602ms/step - loss: 0.3222 - accuracy: 0.8910 - val_loss: 3.6692 - val_accuracy: 0.4907
# Epoch 34/50
# 73/73 [==============================] - 45s 612ms/step - loss: 0.3023 - accuracy: 0.8969 - val_loss: 2.6637 - val_accuracy: 0.5398
# Epoch 35/50
# 73/73 [==============================] - 44s 603ms/step - loss: 0.3544 - accuracy: 0.8852 - val_loss: 1.0609 - val_accuracy: 0.7496
# Epoch 36/50
# 73/73 [==============================] - 44s 603ms/step - loss: 0.2736 - accuracy: 0.9069 - val_loss: 3.0909 - val_accuracy: 0.5787
# Epoch 37/50
# 73/73 [==============================] - 45s 605ms/step - loss: 0.2996 - accuracy: 0.8916 - val_loss: 3.0262 - val_accuracy: 0.5702
# Epoch 38/50
# 73/73 [==============================] - 44s 601ms/step - loss: 0.2532 - accuracy: 0.9136 - val_loss: 7.5521 - val_accuracy: 0.3367
# Epoch 39/50
# 73/73 [==============================] - 44s 599ms/step - loss: 0.3074 - accuracy: 0.8907 - val_loss: 8.7307 - val_accuracy: 0.3858
# Epoch 40/50
# 73/73 [==============================] - 44s 600ms/step - loss: 0.2593 - accuracy: 0.9120 - val_loss: 1.8521 - val_accuracy: 0.6802
# Epoch 41/50
# 73/73 [==============================] - 44s 598ms/step - loss: 0.2329 - accuracy: 0.9274 - val_loss: 1.0891 - val_accuracy: 0.7665
# Epoch 42/50
# 73/73 [==============================] - 44s 598ms/step - loss: 0.2612 - accuracy: 0.9127 - val_loss: 1.4932 - val_accuracy: 0.7242
# Epoch 43/50
# 73/73 [==============================] - 44s 604ms/step - loss: 0.2109 - accuracy: 0.9240 - val_loss: 1.1794 - val_accuracy: 0.7276
# Epoch 44/50
# 73/73 [==============================] - 44s 599ms/step - loss: 0.1834 - accuracy: 0.9418 - val_loss: 1.6729 - val_accuracy: 0.6667
# Epoch 45/50
# 73/73 [==============================] - 44s 600ms/step - loss: 0.4818 - accuracy: 0.8474 - val_loss: 10.9597 - val_accuracy: 0.3130
# Epoch 46/50
# 73/73 [==============================] - 44s 600ms/step - loss: 0.3501 - accuracy: 0.8884 - val_loss: 2.4419 - val_accuracy: 0.6294
# Epoch 47/50
# 73/73 [==============================] - 43s 594ms/step - loss: 0.2857 - accuracy: 0.9109 - val_loss: 1.5123 - val_accuracy: 0.6464
# Epoch 48/50
# 73/73 [==============================] - 44s 601ms/step - loss: 0.2823 - accuracy: 0.8976 - val_loss: 1.1173 - val_accuracy: 0.7665
# Epoch 49/50
# 73/73 [==============================] - 45s 604ms/step - loss: 0.2705 - accuracy: 0.9125 - val_loss: 2.0886 - val_accuracy: 0.6531
# Epoch 50/50
# 73/73 [==============================] - 44s 599ms/step - loss: 0.2245 - accuracy: 0.9192 - val_loss: 1.1308 - val_accuracy: 0.7682

# %%
#plotting all our data using matplotlib
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
#final accuracy mesaures
print("Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# Calculating model accuracy
# 19/19 [==============================] - 4s 202ms/step - loss: 1.1308 - accuracy: 0.7682
# Test Accuracy: 76.81894898414612
